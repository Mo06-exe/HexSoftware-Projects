# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
print("Number of rows: ", data.shape[0])
print("Number of columns: ", data.shape[1])
# Out:
# Number of rows:  4600
# Number of columns:  19

# %%
data.head(5)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
# date             4600 non-null object
# price            4600 non-null float64
# bedrooms         4600 non-null float64
# bathrooms        4600 non-null float64
# sqft_living      4600 non-null int64
# sqft_lot         4600 non-null int64
# floors           4600 non-null float64
# waterfront       4600 non-null int64
# view             4600 non-null int64
# condition        4600 non-null int64
# sqft_above       4600 non-null int64
# sqft_basement    4600 non-null int64
# yr_built         4600 non-null int64
# yr_renovated     4600 non-null int64
# street           4600 non-null object
# city             4600 non-null object
# statezip         4600 non-null object
# country          4600 non-null object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
data = data.rename(columns={"bedrooms": "No. Bedrooms"})
data = data.rename(columns={"bathrooms": "No. Bathrooms"})
data = data.rename(columns={"yr_built": "Year built"})
data = data.rename(columns={"yr_renovated": "Year renovated"})
data = data.rename(columns={"statezip": "State & ZIP code"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
# date                4600 non-null object
# price               4600 non-null float64
# No. Bedrooms        4600 non-null float64
# No. Bathrooms       4600 non-null float64
# sqft_living         4600 non-null int64
# sqft_lot            4600 non-null int64
# floors              4600 non-null float64
# waterfront          4600 non-null int64
# view                4600 non-null int64
# condition           4600 non-null int64
# sqft_above          4600 non-null int64
# sqft_basement       4600 non-null int64
# Year built          4600 non-null int64
# Year renovated      4600 non-null int64
# street              4600 non-null object
# city                4600 non-null object
# State & ZIP code    4600 non-null object
# country             4600 non-null object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
data.head(5)
# Out:
#                   date      price  No. Bedrooms  No. Bathrooms  sqft_living  \
# 0  2014-05-02 00:00:00   313000.0           3.0           1.50         1340
# 1  2014-05-02 00:00:00  2384000.0           5.0           2.50         3650
# 2  2014-05-02 00:00:00   342000.0           3.0           2.00         1930
# 3  2014-05-02 00:00:00   420000.0           3.0           2.25         2000
# 4  2014-05-02 00:00:00   550000.0           4.0           2.50         1940
#
#    sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 0      7912     1.5           0     0          3        1340              0
# 1      9050     2.0           0     4          5        3370            280
# 2     11947     1.0           0     0          4        1930              0
# 3      8030     1.0           0     0          4        1000           1000
# 4     10500     1.0           0     0          4        1140            800
#
# ...

# %%
data.describe()
# Out:
#               price  No. Bedrooms  No. Bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03   4600.000000    4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05      3.400870       2.160815   2139.346957  1.485252e+04
# std    5.638347e+05      0.908848       0.783781    963.206916  3.588444e+04
# min    0.000000e+00      0.000000       0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05      3.000000       1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05      3.000000       2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05      4.000000       2.500000   2620.000000  1.100125e+04
# max    2.659000e+07      9.000000       8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# ...

# %%
data["No. Bedrooms"] = data["No. Bedrooms"].astype(int)

# %%
data["No. Bathrooms"] = data["No. Bathrooms"].astype(int)

# %%
data["floors"] = data["floors"].astype(int)

# %%
data.head(5)
# Out:
#                   date      price  No. Bedrooms  No. Bathrooms  sqft_living  \
# 0  2014-05-02 00:00:00   313000.0             3              1         1340
# 1  2014-05-02 00:00:00  2384000.0             5              2         3650
# 2  2014-05-02 00:00:00   342000.0             3              2         1930
# 3  2014-05-02 00:00:00   420000.0             3              2         2000
# 4  2014-05-02 00:00:00   550000.0             4              2         1940
#
#    sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 0      7912       1           0     0          3        1340              0
# 1      9050       2           0     4          5        3370            280
# 2     11947       1           0     0          4        1930              0
# 3      8030       1           0     0          4        1000           1000
# 4     10500       1           0     0          4        1140            800
#
# ...

# %%
plt.hist(data['condition'], bins = 5)
plt.xlabel('Condition')
plt.ylabel('No. of houses')
plt.title('Condition of the Houses in Boston')
plt.show()

# %%
X = data[["sqft_living"]]
Y = data["price"]

model = LinearRegression()
model.fit(X, Y)
data["predicted_price"] = model.predict(X)

# %%
plt.scatter(data["sqft_living"], data["price"], color="blue", label="Actual Data")

plt.plot(data["sqft_living"], data["predicted_price"], color="red", linewidth=2, label="Regression Line")

plt.xlabel("Square Footage")
plt.ylabel("Price")
plt.title("Linear Regression: House Price vs. Square Footage")
plt.legend()

plt.show()
